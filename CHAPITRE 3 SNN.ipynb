# %% [markdown]
# # 1. Importation des Librairies

# %%
# importer les Packages
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 2.Charger les donnees

# %%
# # Chargement des donnees
data = pd.read_csv('Data/DDoS_dataset-checkpoint.csv')
data.head()
# Out:
#       dt  switch       src       dst  pktcount  bytecount  dur   dur_nsec  \
# 0  11425       1  10.0.0.1  10.0.0.8     45304   48294064  100  716000000
# 1  11605       1  10.0.0.1  10.0.0.8    126395  134737070  280  734000000
# 2  11425       1  10.0.0.2  10.0.0.8     90333   96294978  200  744000000
# 3  11425       1  10.0.0.2  10.0.0.8     90333   96294978  200  744000000
# 4  11425       1  10.0.0.2  10.0.0.8     90333   96294978  200  744000000
#
#         tot_dur  flows  ...  pktrate  Pairflow  Protocol  port_no   tx_bytes  \
# 0  1.010000e+11      3  ...      451         0       UDP        3  143928631
# 1  2.810000e+11      2  ...      451         0       UDP        4       3842
# 2  2.010000e+11      3  ...      451         0       UDP        1       3795
# 3  2.010000e+11      3  ...      451         0       UDP        2       3688
# 4  2.010000e+11      3  ...      451         0       UDP        3       3413
#
#   rx_bytes  tx_kbps  rx_kbps  tot_kbps  label
# 0     3917        0      0.0       0.0      0
# 1     3520        0      0.0       0.0      0
# 2     1242        0      0.0       0.0      0
# 3     1492        0      0.0       0.0      0
# 4     3665        0      0.0       0.0      0
#
# [5 rows x 23 columns]

# %% [markdown]
# # 3.Analyse de données

# %%
#  Analyse de données
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104345 entries, 0 to 104344
# Data columns (total 23 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   dt           104345 non-null  int64
#  1   switch       104345 non-null  int64
#  2   src          104345 non-null  object
#  3   dst          104345 non-null  object
#  4   pktcount     104345 non-null  int64
#  5   bytecount    104345 non-null  int64
#  6   dur          104345 non-null  int64
#  7   dur_nsec     104345 non-null  int64
#  8   tot_dur      104345 non-null  float64
#  9   flows        104345 non-null  int64
#  10  packetins    104345 non-null  int64
#  11  pktperflow   104345 non-null  int64
#  12  byteperflow  104345 non-null  int64
#  13  pktrate      104345 non-null  int64
#  14  Pairflow     104345 non-null  int64
#  15  Protocol     104345 non-null  object
#  16  port_no      104345 non-null  int64
#  17  tx_bytes     104345 non-null  int64
#  18  rx_bytes     104345 non-null  int64
#  19  tx_kbps      104345 non-null  int64
#  20  rx_kbps      103839 non-null  float64
#  21  tot_kbps     103839 non-null  float64
#  22  label        104345 non-null  int64
# dtypes: float64(3), int64(17), object(3)
# memory usage: 18.3+ MB

# %%
data['src'].unique()
# Out:
# array(['10.0.0.1', '10.0.0.2', '10.0.0.4', '10.0.0.10', '10.0.0.3',
#        '10.0.0.5', '10.0.0.13', '10.0.0.6', '10.0.0.20', '10.0.0.11',
#        '10.0.0.12', '10.0.0.18', '10.0.0.8', '10.0.0.7', '10.0.0.9',
#        '10.0.0.14', '10.0.0.15', '10.0.0.16', '10.0.0.17'], dtype=object)

# %%
data['dst'].unique()
# Out:
# array(['10.0.0.8', '10.0.0.7', '10.0.0.3', '10.0.0.5', '10.0.0.10',
#        '10.0.0.13', '10.0.0.1', '10.0.0.11', '10.0.0.2', '10.0.0.4',
#        '10.0.0.9', '10.0.0.6', '10.0.0.14', '10.0.0.15', '10.0.0.12',
#        '10.0.0.16', '10.0.0.17', '10.0.0.18'], dtype=object)

# %%
data['Protocol'].unique()
# Out:
# array(['UDP', 'TCP', 'ICMP'], dtype=object)

# %%
data.drop(columns='src', inplace=True, axis=1)
data.drop(columns='dst', inplace=True, axis=1)
data.head()
# Out:
#       dt  switch  pktcount  bytecount  dur   dur_nsec       tot_dur  flows  \
# 0  11425       1     45304   48294064  100  716000000  1.010000e+11      3
# 1  11605       1    126395  134737070  280  734000000  2.810000e+11      2
# 2  11425       1     90333   96294978  200  744000000  2.010000e+11      3
# 3  11425       1     90333   96294978  200  744000000  2.010000e+11      3
# 4  11425       1     90333   96294978  200  744000000  2.010000e+11      3
#
#    packetins  pktperflow  ...  pktrate  Pairflow  Protocol port_no   tx_bytes  \
# 0       1943       13535  ...      451         0       UDP       3  143928631
# 1       1943       13531  ...      451         0       UDP       4       3842
# 2       1943       13534  ...      451         0       UDP       1       3795
# 3       1943       13534  ...      451         0       UDP       2       3688
# 4       1943       13534  ...      451         0       UDP       3       3413
#
#    rx_bytes  tx_kbps  rx_kbps  tot_kbps  label
# 0      3917        0      0.0       0.0      0
# 1      3520        0      0.0       0.0      0
# 2      1242        0      0.0       0.0      0
# 3      1492        0      0.0       0.0      0
# 4      3665        0      0.0       0.0      0
#
# [5 rows x 21 columns]

# %% [markdown]
# # 4. Prétraitement des données

# %%
encoder = LabelEncoder()

# %%
data['Protocol'] = encoder.fit_transform(data['Protocol'])
data.head()
# Out:
#       dt  switch  pktcount  bytecount  dur   dur_nsec       tot_dur  flows  \
# 0  11425       1     45304   48294064  100  716000000  1.010000e+11      3
# 1  11605       1    126395  134737070  280  734000000  2.810000e+11      2
# 2  11425       1     90333   96294978  200  744000000  2.010000e+11      3
# 3  11425       1     90333   96294978  200  744000000  2.010000e+11      3
# 4  11425       1     90333   96294978  200  744000000  2.010000e+11      3
#
#    packetins  pktperflow  ...  pktrate  Pairflow  Protocol  port_no  \
# 0       1943       13535  ...      451         0         2        3
# 1       1943       13531  ...      451         0         2        4
# 2       1943       13534  ...      451         0         2        1
# 3       1943       13534  ...      451         0         2        2
# 4       1943       13534  ...      451         0         2        3
#
#     tx_bytes  rx_bytes  tx_kbps  rx_kbps  tot_kbps  label
# 0  143928631      3917        0      0.0       0.0      0
# 1       3842      3520        0      0.0       0.0      0
# 2       3795      1242        0      0.0       0.0      0
# 3       3688      1492        0      0.0       0.0      0
# 4       3413      3665        0      0.0       0.0      0
#
# [5 rows x 21 columns]

# %%
data['Protocol'].unique()
# Out:
# array([2, 1, 0])

# %%
data.isnull().sum()
# Out:
# dt               0
# switch           0
# pktcount         0
# bytecount        0
# dur              0
# dur_nsec         0
# tot_dur          0
# flows            0
# packetins        0
# pktperflow       0
# byteperflow      0
# pktrate          0
# Pairflow         0
# Protocol         0
# port_no          0
# tx_bytes         0
# rx_bytes         0
# tx_kbps          0
# rx_kbps        506
# tot_kbps       506
# label            0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
# Gestion des valeurs manquantes
data['rx_kbps'].fillna(data['rx_kbps'].mean(), inplace=True)
data['tot_kbps'].fillna(data['tot_kbps'].mean(), inplace=True)
data.isnull().sum()
# Out:
# dt             0
# switch         0
# pktcount       0
# bytecount      0
# dur            0
# dur_nsec       0
# tot_dur        0
# flows          0
# packetins      0
# pktperflow     0
# byteperflow    0
# pktrate        0
# Pairflow       0
# Protocol       0
# port_no        0
# tx_bytes       0
# rx_bytes       0
# tx_kbps        0
# rx_kbps        0
# tot_kbps       0
# label          0
# dtype: int64

# %%
data
# Out:
#            dt  switch  pktcount  bytecount  dur   dur_nsec       tot_dur  \
# 0       11425       1     45304   48294064  100  716000000  1.010000e+11
# 1       11605       1    126395  134737070  280  734000000  2.810000e+11
# 2       11425       1     90333   96294978  200  744000000  2.010000e+11
# 3       11425       1     90333   96294978  200  744000000  2.010000e+11
# 4       11425       1     90333   96294978  200  744000000  2.010000e+11
# ...       ...     ...       ...        ...  ...        ...           ...
# 104340   5262       3        79       7742   81  842000000  8.184200e+10
# 104341   5262       3        79       7742   81  842000000  8.184200e+10
# 104342   5262       3        31       3038   31  805000000  3.180500e+10
# 104343   5262       3        31       3038   31  805000000  3.180500e+10
# 104344   5262       3        31       3038   31  805000000  3.180500e+10
#
#         flows  packetins  pktperflow  ...  pktrate  Pairflow  Protocol  \
# 0           3       1943       13535  ...      451         0         2
# 1           2       1943       13531  ...      451         0         2
# 2           3       1943       13534  ...      451         0         2
# 3           3       1943       13534  ...      451         0         2
# 4           3       1943       13534  ...      451         0         2
# ...       ...        ...         ...  ...      ...       ...       ...
# 104340      5         10          29  ...        0         0         0
# 104341      5         10          29  ...        0         0         0
# 104342      5         10          30  ...        1         0         0
# 104343      5         10          30  ...        1         0         0
# 104344      5         10          30  ...        1         0         0
#
#         port_no   tx_bytes  rx_bytes  tx_kbps  rx_kbps  tot_kbps  label
# 0             3  143928631      3917        0      0.0       0.0      0
# 1             4       3842      3520        0      0.0       0.0      0
# 2             1       3795      1242        0      0.0       0.0      0
# 3             2       3688      1492        0      0.0       0.0      0
# 4             3       3413      3665        0      0.0       0.0      0
# ...         ...        ...       ...      ...      ...       ...    ...
# 104340        1      15209     12720        1      1.0       2.0      0
# 104341        3      15099     14693        1      1.0       2.0      0
# 104342        2       3409      3731        0      0.0       0.0      0
# 104343        1      15209     12720        1      1.0       2.0      0
# 104344        3      15099     14693        1      1.0       2.0      0
#
# [104345 rows x 21 columns]

# %% [markdown]
# # 5. Diviser les données : Train et Test

# %%
data.columns
# Out:
# Index(['dt', 'switch', 'pktcount', 'bytecount', 'dur', 'dur_nsec', 'tot_dur',
#        'flows', 'packetins', 'pktperflow', 'byteperflow', 'pktrate',
#        'Pairflow', 'Protocol', 'port_no', 'tx_bytes', 'rx_bytes', 'tx_kbps',
#        'rx_kbps', 'tot_kbps', 'label'],
#       dtype='object')

# %%
#Étape 5 : Diviser les données : Train et Test (Normaliser les données)
#X = data.drop(columns='label', inplace=True, axis=1)
#y = data['label']
X = data.iloc[ : , :-1]
y = data.iloc[ : , -1]

# %%
X
# Out:
#            dt  switch  pktcount  bytecount  dur   dur_nsec       tot_dur  \
# 0       11425       1     45304   48294064  100  716000000  1.010000e+11
# 1       11605       1    126395  134737070  280  734000000  2.810000e+11
# 2       11425       1     90333   96294978  200  744000000  2.010000e+11
# 3       11425       1     90333   96294978  200  744000000  2.010000e+11
# 4       11425       1     90333   96294978  200  744000000  2.010000e+11
# ...       ...     ...       ...        ...  ...        ...           ...
# 104340   5262       3        79       7742   81  842000000  8.184200e+10
# 104341   5262       3        79       7742   81  842000000  8.184200e+10
# 104342   5262       3        31       3038   31  805000000  3.180500e+10
# 104343   5262       3        31       3038   31  805000000  3.180500e+10
# 104344   5262       3        31       3038   31  805000000  3.180500e+10
#
#         flows  packetins  pktperflow  byteperflow  pktrate  Pairflow  \
# 0           3       1943       13535     14428310      451         0
# 1           2       1943       13531     14424046      451         0
# 2           3       1943       13534     14427244      451         0
# 3           3       1943       13534     14427244      451         0
# 4           3       1943       13534     14427244      451         0
# ...       ...        ...         ...          ...      ...       ...
# 104340      5         10          29         2842        0         0
# 104341      5         10          29         2842        0         0
# 104342      5         10          30         2940        1         0
# 104343      5         10          30         2940        1         0
# 104344      5         10          30         2940        1         0
#
#         Protocol  port_no   tx_bytes  rx_bytes  tx_kbps  rx_kbps  tot_kbps
# 0              2        3  143928631      3917        0      0.0       0.0
# 1              2        4       3842      3520        0      0.0       0.0
# 2              2        1       3795      1242        0      0.0       0.0
# 3              2        2       3688      1492        0      0.0       0.0
# 4              2        3       3413      3665        0      0.0       0.0
# ...          ...      ...        ...       ...      ...      ...       ...
# 104340         0        1      15209     12720        1      1.0       2.0
# 104341         0        3      15099     14693        1      1.0       2.0
# 104342         0        2       3409      3731        0      0.0       0.0
# 104343         0        1      15209     12720        1      1.0       2.0
# 104344         0        3      15099     14693        1      1.0       2.0
#
# [104345 rows x 20 columns]

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 104340    0
# 104341    0
# 104342    0
# 104343    0
# 104344    0
# Name: label, Length: 104345, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.23, random_state=40)

# %%
print("X-train:", X_train.shape)
print("X-test:", X_test.shape)
print("y-train:", y_train.shape)
print("y-train:", y_test.shape)
# Out:
# X-train: (80345, 20)
# X-test: (24000, 20)
# y-train: (80345,)
# y-train: (24000,)

# %%
# 6. Construire le SNN( Shallo

# %%
# Creation du model
model = Sequential()

# %%
model.add(Dense(10, input_shape=(20,), activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_10 (Dense)                │ (None, 10)             │           210 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 221 (884.00 B)
#  Trainable params: 221 (884.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# Entrainement du modele
history = model.fit(X_train, y_train, epochs=30, verbose=1, validation_data=(X_test, y_test))
# Out:
# Epoch 1/30
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.5208 - loss: 2152122112.0000 - val_accuracy: 0.5923 - val_loss: 26297730.0000
# Epoch 2/30
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.5488 - loss: 53821772.0000 - val_accuracy: 0.6087 - val_loss: 140313008.0000
# Epoch 3/30
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.5573 - loss: 58771432.0000 - val_accuracy: 0.5638 - val_loss: 31225914.0000
# Epoch 4/30
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.5765 - loss: 45053568.0000 - val_accuracy: 0.6121 - val_loss: 32134218.0000
# Epoch 5/30
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.5735 - loss: 54175552.0000 - val_accuracy: 0.6100 - val_loss: 100474456.0000
# Epoch 6/30
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.5816 - loss: 51491484.0000 - val_accuracy: 0.6646 - val_loss: 14406921.0000
# Epoch 7/30
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.5860 - loss: 43136988.0000 - val_accuracy: 0.5073 - val_loss: 17378452.0000
# Epoch 8/30
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.5928 - loss: 41654364.0000 - val_accuracy: 0.6099 - val_loss: 157780000.0000
# Epoch 9/30
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.5906 - loss: 49946584.0000 - val_accuracy: 0.4492 - val_loss: 20311860.0000
# Epoch 10/30
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.5923 - loss: 46805040.0000 - val_accuracy: 0.6288 - val_loss: 73640936.0000
# Epoch 11/30
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.5961 - loss: 47169380.0000 - val_accuracy: 0.6308 - val_loss: 62822516.0000
# Epoch 12/30
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.5958 - loss: 47438808.0000 - val_accuracy: 0.6156 - val_loss: 196534192.0000
# Epoch 13/30
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.5944 - loss: 59985884.0000 - val_accuracy: 0.4152 - val_loss: 35411316.0000
# Epoch 14/30
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.6002 - loss: 46569728.0000 - val_accuracy: 0.6204 - val_loss: 112858992.0000
# Epoch 15/30
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.5953 - loss: 49432072.0000 - val_accuracy: 0.6815 - val_loss: 14500884.0000
# Epoch 16/30
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.6079 - loss: 41608632.0000 - val_accuracy: 0.6795 - val_loss: 14295040.0000
# Epoch 17/30
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.6076 - loss: 41346388.0000 - val_accuracy: 0.4411 - val_loss: 22300356.0000
# Epoch 18/30
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.6076 - loss: 41740320.0000 - val_accuracy: 0.4251 - val_loss: 44875044.0000
# Epoch 19/30
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.6047 - loss: 43737808.0000 - val_accuracy: 0.6638 - val_loss: 20503488.0000
# Epoch 20/30
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.6080 - loss: 40283680.0000 - val_accuracy: 0.4225 - val_loss: 39105240.0000
# Epoch 21/30
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.6101 - loss: 38499660.0000 - val_accuracy: 0.6373 - val_loss: 27733096.0000
# Epoch 22/30
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.6128 - loss: 38527832.0000 - val_accuracy: 0.6357 - val_loss: 38778592.0000
# Epoch 23/30
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.6125 - loss: 39959964.0000 - val_accuracy: 0.6770 - val_loss: 14023392.0000
# Epoch 24/30
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.6075 - loss: 37036128.0000 - val_accuracy: 0.4243 - val_loss: 59859868.0000
# Epoch 25/30
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.6110 - loss: 42348776.0000 - val_accuracy: 0.6647 - val_loss: 19378510.0000
# Epoch 26/30
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.6105 - loss: 43129920.0000 - val_accuracy: 0.4169 - val_loss: 130725328.0000
# Epoch 27/30
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.6158 - loss: 36373104.0000 - val_accuracy: 0.6482 - val_loss: 45107384.0000
# Epoch 28/30
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.6223 - loss: 30451410.0000 - val_accuracy: 0.4263 - val_loss: 55224112.0000
# Epoch 29/30
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.6123 - loss: 38729696.0000 - val_accuracy: 0.6825 - val_loss: 13587640.0000
# Epoch 30/30
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.6195 - loss: 31704792.0000 - val_accuracy: 0.6894 - val_loss: 12898058.0000

# %% [markdown]
# # 7. Visualiser l’évolution de l’entrainement du réseau de neurone

# %%
history

# %%
epoch_accuracy = history.history['accuracy']
epoch_loss = history.history['loss']

epoch_val_accuracy = history.history['val_accuracy']
epoch_val_loss = history.history['val_loss']

# %%
plt.figure(figsize=(15, 6))
plt.plot(range(0, len(epoch_accuracy)), epoch_accuracy, color='blue', label='Training Accuracy')
plt.plot(range(0, len(epoch_loss)), epoch_loss, color='red', label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Valeur')
plt.title('Accuracy Vs Loss')
plt.legend()
plt.plot()
plt.show()

# %%
plt.figure(figsize=(15, 6))
plt.plot(range(0, len(epoch_accuracy)), epoch_accuracy, color='blue', label='Training Accuracy')
plt.plot(range(0, len(epoch_val_accuracy)), epoch_val_accuracy, color='red', label='Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training Accuracy Vs Test Accuracy')
plt.legend()
plt.plot()
plt.show()

# %%
plt.figure(figsize=(15, 6))
plt.plot(range(0, len(epoch_loss)), epoch_loss, color='blue', label='Training Loss')
plt.plot(range(0, len(epoch_val_loss)), epoch_val_loss, color='red', label='Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss Vs Test Loss')
plt.legend()
plt.plot()
plt.show()

# %% [markdown]
# # Étape 8 : Evaluer le modèle

# %%
# Étape 8 : Evaluer le modèle
model.evaluate(X_test, y_test)
# Out:
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6894 - loss: 13151207.0000
# [12898058.0, 0.6894166469573975]

# %% [markdown]
# # Deep learning Model

# %%
# premiere couche
model_dnn= Sequential()
model_dnn.add(Dense(3, input_shape=(20,),activation='relu'))
# deuxieme couche
model_dnn.add(Dense(32,activation='relu'))
model_dnn.add(Dense(64,activation='relu'))
# couche de sortie
model_dnn.add(Dense(1, activation='sigmoid'))
# compiler le modele
model_dnn.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model_dnn.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_12 (Dense)                │ (None, 3)              │            63 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 32)             │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 64)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,368 (9.25 KB)
#  Trainable params: 2,368 (9.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history=model_dnn.fit(X_train,y_train, epochs= 5, verbose= 1, validation_data=(X_test,y_test))
# Out:
# Epoch 1/5
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.5347 - loss: 113508720.0000 - val_accuracy: 0.6143 - val_loss: 37018432.0000
# Epoch 2/5
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.5393 - loss: 25851432.0000 - val_accuracy: 0.6100 - val_loss: 955694.4375
# Epoch 3/5
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.5398 - loss: 5182538.5000 - val_accuracy: 0.3988 - val_loss: 82063.7344
# Epoch 4/5
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.5808 - loss: 297039.2500 - val_accuracy: 0.6087 - val_loss: 1152.8972
# Epoch 5/5
# 2511/2511 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.6096 - loss: 0.6687 - val_accuracy: 0.6087 - val_loss: 1156.8925

# %%
X_train, X_test, y_train, y_test=train_test_split(X,y, test_size=0.3,random_state=40)
scaler=StandardScaler()

X_train= scaler.fit_transform(X_train)
X_test= scaler.fit_transform(X_test)
X_test, X_val, y_test, y_val=train_test_split(X_test, y_test, test_size=0.8,random_state=40)
